# %%
import sys
import keras
import cv2
import numpy as np
import matplotlib.pyplot as plt
import skimage
import math
import os
import h5py
from keras.models import Sequential
from keras.layers import Conv2D
from keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
xtrain_path=r"/content/drive/My Drive/srcnn/dataset/train/low_res"
ytrain_path=r"/content/drive/My Drive/srcnn/dataset/train/high_res"

# %%
low_res_path=os.listdir(xtrain_path)
high_res_path=os.listdir(ytrain_path)

# %%
low_res_path[0]
# Out:
# '144.png'

# %%
x_train_path=[]
y_train_path=[]
for i in range(0,len(low_res_path)):
    x_train_path.append(xtrain_path+"/"+low_res_path[i])
    y_train_path.append(ytrain_path+"/"+high_res_path[i])

# %%
x_train_path= sorted(x_train_path)
y_train_path=sorted(y_train_path)

# %%
Random_Crop = 30
Patch_size = 32
label_size = 20
conv_side = 6
scale = 2


def prepare_data(_path):
    nums = _path.__len__()

    data = np.zeros((nums * Random_Crop, 1, Patch_size, Patch_size), dtype=np.double)
    label = np.zeros((nums * Random_Crop, 1, label_size, label_size), dtype=np.double)

    for i in _path:
        name = i
        hr_img = cv2.imread(name, cv2.IMREAD_COLOR)
        shape = hr_img.shape

        hr_img = cv2.cvtColor(hr_img, cv2.COLOR_BGR2YCrCb)
        hr_img = hr_img[:, :, 0]

        # two resize operation to produce training data and labels
        lr_img = cv2.resize(hr_img, (shape[1] / scale, shape[0] / scale))
        lr_img = cv2.resize(lr_img, (shape[1], shape[0]))

        # produce Random_Crop random coordinate to crop training img
        Points_x = np.random.randint(0, min(shape[0], shape[1]) - Patch_size, Random_Crop)
        Points_y = np.random.randint(0, min(shape[0], shape[1]) - Patch_size, Random_Crop)

        for j in range(Random_Crop):
            lr_patch = lr_img[Points_x[j]: Points_x[j] + Patch_size, Points_y[j]: Points_y[j] + Patch_size]
            hr_patch = hr_img[Points_x[j]: Points_x[j] + Patch_size, Points_y[j]: Points_y[j] + Patch_size]

            lr_patch = lr_patch.astype(float) / 255.
            hr_patch = hr_patch.astype(float) / 255.

            data[i * Random_Crop + j, 0, :, :] = lr_patch
            label[i * Random_Crop + j, 0, :, :] = hr_patch[conv_side: -conv_side, conv_side: -conv_side]
            # cv2.imshow("lr", lr_patch)
            # cv2.imshow("hr", hr_patch)
            # cv2.waitKey(0)
    return data, label

# %%
BLOCK_STEP = 16
BLOCK_SIZE = 32


def prepare_crop_data(_path):
    nums = _path.__len__()

    data = []
    label = []

    for i in _path:
        name = i
        hr_img = cv2.imread(name, cv2.IMREAD_COLOR)
        hr_img = cv2.cvtColor(hr_img, cv2.COLOR_BGR2YCrCb)
        hr_img = hr_img[:, :, 0]
        shape = hr_img.shape

        # two resize operation to produce training data and labels
        lr_img = cv2.resize(hr_img, (shape[1] // scale, shape[0] // scale))
        lr_img = cv2.resize(lr_img, (shape[1], shape[0]))

        width_num = (shape[0] - (BLOCK_SIZE - BLOCK_STEP) * 2) // BLOCK_STEP
        height_num = (shape[1] - (BLOCK_SIZE - BLOCK_STEP) * 2) // BLOCK_STEP
        for k in range(width_num):
            for j in range(height_num):
                x = k * BLOCK_STEP
                y = j * BLOCK_STEP
                hr_patch = hr_img[x: x + BLOCK_SIZE, y: y + BLOCK_SIZE]
                lr_patch = lr_img[x: x + BLOCK_SIZE, y: y + BLOCK_SIZE]

                lr_patch = lr_patch.astype(float) / 255.
                hr_patch = hr_patch.astype(float) / 255.

                lr = np.zeros((1, Patch_size, Patch_size), dtype=np.double)
                hr = np.zeros((1, label_size, label_size), dtype=np.double)

                lr[0, :, :] = lr_patch
                hr[0, :, :] = hr_patch[conv_side: -conv_side, conv_side: -conv_side]

                data.append(lr)
                label.append(hr)

    data = np.array(data, dtype=float)
    label = np.array(label, dtype=float)
    return data, label

# %%
def write_hdf5(data, labels, output_filename):
    """
    This function is used to save image data and its label(s) to hdf5 file.
    output_file.h5,contain data and label
    """

    x = data.astype(np.float32)
    y = labels.astype(np.float32)

    with h5py.File(output_filename, 'w') as h:
        h.create_dataset('data', data=x, shape=x.shape)
        h.create_dataset('label', data=y, shape=y.shape)
        # h.create_dataset()

# %%
def read_training_data(file):
    with h5py.File(file, 'r') as hf:
        data = np.array(hf.get('data'))
        label = np.array(hf.get('label'))
        train_data = np.transpose(data, (0, 2, 3, 1))
        train_label = np.transpose(label, (0, 2, 3, 1))
        return train_data, train_label

# %%
traindata, trainlabel = prepare_crop_data(y_train_path)

# %%
write_hdf5(traindata, trainlabel, path+"/crop_train.h5")

# %%
srcnn=Sequential()
srcnn.add(Conv2D(filters=128, kernel_size = (9, 9), kernel_initializer='glorot_uniform',
                 activation='relu', padding='valid', use_bias=True, input_shape=(None,None,1)))
srcnn.add(Conv2D(filters=64, kernel_size = (3, 3), kernel_initializer='glorot_uniform',
                     activation='relu', padding='same', use_bias=True))
srcnn.add(Conv2D(filters=1, kernel_size = (5, 5), kernel_initializer='glorot_uniform',
                     activation='linear', padding='valid', use_bias=True))
adam = Adam(lr=0.0001)
srcnn.compile(optimizer=adam, loss='mean_squared_error', metrics=['mean_squared_error'])
srcnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, None, None, 128)   10496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 64)    73792
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, None, None, 1)     1601
# =================================================================
# Total params: 85,889
# Trainable params: 85,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
ytrain.shapeee
# Out:
# (685, 256, 256, 3)

# %%
train_data = np.transpose(traindata, (0, 2, 3, 1))
train_label = np.transpose(trainlabel, (0, 2, 3, 1))
train_data.shape
# Out:
# (134260, 32, 32, 1)

# %%
srcnn.fit(train_data,train_label,batch_size=128,epochs=150,validation_split=0.2)
history=srcnn.history
# Out:
# Epoch 1/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.5069e-04 - mean_squared_error: 8.5069e-04 - val_loss: 8.7359e-04 - val_mean_squared_error: 8.7359e-04
# Epoch 2/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4984e-04 - mean_squared_error: 8.4984e-04 - val_loss: 8.7654e-04 - val_mean_squared_error: 8.7654e-04
# Epoch 3/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4968e-04 - mean_squared_error: 8.4968e-04 - val_loss: 8.7728e-04 - val_mean_squared_error: 8.7728e-04
# Epoch 4/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4872e-04 - mean_squared_error: 8.4872e-04 - val_loss: 8.7473e-04 - val_mean_squared_error: 8.7473e-04
# Epoch 5/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4849e-04 - mean_squared_error: 8.4849e-04 - val_loss: 8.7584e-04 - val_mean_squared_error: 8.7584e-04
# Epoch 6/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4801e-04 - mean_squared_error: 8.4801e-04 - val_loss: 8.7712e-04 - val_mean_squared_error: 8.7712e-04
# Epoch 7/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4722e-04 - mean_squared_error: 8.4722e-04 - val_loss: 8.7417e-04 - val_mean_squared_error: 8.7417e-04
# Epoch 8/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4671e-04 - mean_squared_error: 8.4671e-04 - val_loss: 8.7276e-04 - val_mean_squared_error: 8.7276e-04
# Epoch 9/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4648e-04 - mean_squared_error: 8.4648e-04 - val_loss: 8.7443e-04 - val_mean_squared_error: 8.7443e-04
# Epoch 10/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4605e-04 - mean_squared_error: 8.4605e-04 - val_loss: 8.7209e-04 - val_mean_squared_error: 8.7209e-04
# Epoch 11/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4508e-04 - mean_squared_error: 8.4508e-04 - val_loss: 8.7134e-04 - val_mean_squared_error: 8.7134e-04
# Epoch 12/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4530e-04 - mean_squared_error: 8.4530e-04 - val_loss: 8.7145e-04 - val_mean_squared_error: 8.7144e-04
# Epoch 13/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4383e-04 - mean_squared_error: 8.4383e-04 - val_loss: 8.7090e-04 - val_mean_squared_error: 8.7090e-04
# Epoch 14/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.4378e-04 - mean_squared_error: 8.4378e-04 - val_loss: 8.7541e-04 - val_mean_squared_error: 8.7541e-04
# Epoch 15/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4384e-04 - mean_squared_error: 8.4384e-04 - val_loss: 8.7072e-04 - val_mean_squared_error: 8.7072e-04
# Epoch 16/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4283e-04 - mean_squared_error: 8.4283e-04 - val_loss: 8.7136e-04 - val_mean_squared_error: 8.7136e-04
# Epoch 17/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4294e-04 - mean_squared_error: 8.4294e-04 - val_loss: 8.7281e-04 - val_mean_squared_error: 8.7281e-04
# Epoch 18/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4233e-04 - mean_squared_error: 8.4233e-04 - val_loss: 8.7240e-04 - val_mean_squared_error: 8.7240e-04
# Epoch 19/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.4274e-04 - mean_squared_error: 8.4274e-04 - val_loss: 8.7747e-04 - val_mean_squared_error: 8.7747e-04
# Epoch 20/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4140e-04 - mean_squared_error: 8.4140e-04 - val_loss: 8.7184e-04 - val_mean_squared_error: 8.7184e-04
# Epoch 21/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.4090e-04 - mean_squared_error: 8.4090e-04 - val_loss: 8.6837e-04 - val_mean_squared_error: 8.6837e-04
# Epoch 22/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.4051e-04 - mean_squared_error: 8.4051e-04 - val_loss: 8.6953e-04 - val_mean_squared_error: 8.6953e-04
# Epoch 23/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3986e-04 - mean_squared_error: 8.3986e-04 - val_loss: 8.6967e-04 - val_mean_squared_error: 8.6967e-04
# Epoch 24/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.3968e-04 - mean_squared_error: 8.3968e-04 - val_loss: 8.6750e-04 - val_mean_squared_error: 8.6750e-04
# Epoch 25/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3945e-04 - mean_squared_error: 8.3945e-04 - val_loss: 8.7141e-04 - val_mean_squared_error: 8.7141e-04
# Epoch 26/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.3919e-04 - mean_squared_error: 8.3919e-04 - val_loss: 8.7181e-04 - val_mean_squared_error: 8.7181e-04
# Epoch 27/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3816e-04 - mean_squared_error: 8.3816e-04 - val_loss: 8.9052e-04 - val_mean_squared_error: 8.9052e-04
# Epoch 28/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3841e-04 - mean_squared_error: 8.3841e-04 - val_loss: 8.6590e-04 - val_mean_squared_error: 8.6590e-04
# Epoch 29/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3773e-04 - mean_squared_error: 8.3773e-04 - val_loss: 8.6675e-04 - val_mean_squared_error: 8.6675e-04
# Epoch 30/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3725e-04 - mean_squared_error: 8.3725e-04 - val_loss: 8.6953e-04 - val_mean_squared_error: 8.6953e-04
# Epoch 31/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3727e-04 - mean_squared_error: 8.3727e-04 - val_loss: 8.6475e-04 - val_mean_squared_error: 8.6475e-04
# Epoch 32/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3625e-04 - mean_squared_error: 8.3625e-04 - val_loss: 8.6758e-04 - val_mean_squared_error: 8.6758e-04
# Epoch 33/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3624e-04 - mean_squared_error: 8.3624e-04 - val_loss: 8.7686e-04 - val_mean_squared_error: 8.7686e-04
# Epoch 34/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3595e-04 - mean_squared_error: 8.3595e-04 - val_loss: 8.6435e-04 - val_mean_squared_error: 8.6435e-04
# Epoch 35/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3540e-04 - mean_squared_error: 8.3540e-04 - val_loss: 8.6774e-04 - val_mean_squared_error: 8.6774e-04
# Epoch 36/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3615e-04 - mean_squared_error: 8.3615e-04 - val_loss: 8.6853e-04 - val_mean_squared_error: 8.6853e-04
# Epoch 37/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3501e-04 - mean_squared_error: 8.3501e-04 - val_loss: 8.6871e-04 - val_mean_squared_error: 8.6871e-04
# Epoch 38/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3471e-04 - mean_squared_error: 8.3471e-04 - val_loss: 8.6740e-04 - val_mean_squared_error: 8.6740e-04
# Epoch 39/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3466e-04 - mean_squared_error: 8.3466e-04 - val_loss: 8.6599e-04 - val_mean_squared_error: 8.6599e-04
# Epoch 40/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3396e-04 - mean_squared_error: 8.3396e-04 - val_loss: 8.6498e-04 - val_mean_squared_error: 8.6498e-04
# Epoch 41/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3352e-04 - mean_squared_error: 8.3352e-04 - val_loss: 8.6477e-04 - val_mean_squared_error: 8.6477e-04
# Epoch 42/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3325e-04 - mean_squared_error: 8.3325e-04 - val_loss: 8.6707e-04 - val_mean_squared_error: 8.6707e-04
# Epoch 43/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.3245e-04 - mean_squared_error: 8.3245e-04 - val_loss: 8.6751e-04 - val_mean_squared_error: 8.6751e-04
# Epoch 44/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3340e-04 - mean_squared_error: 8.3340e-04 - val_loss: 8.6425e-04 - val_mean_squared_error: 8.6425e-04
# Epoch 45/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3222e-04 - mean_squared_error: 8.3222e-04 - val_loss: 8.6495e-04 - val_mean_squared_error: 8.6495e-04
# Epoch 46/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3166e-04 - mean_squared_error: 8.3166e-04 - val_loss: 8.6967e-04 - val_mean_squared_error: 8.6967e-04
# Epoch 47/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3220e-04 - mean_squared_error: 8.3220e-04 - val_loss: 8.8205e-04 - val_mean_squared_error: 8.8205e-04
# Epoch 48/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.3162e-04 - mean_squared_error: 8.3162e-04 - val_loss: 8.6412e-04 - val_mean_squared_error: 8.6412e-04
# Epoch 49/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.3129e-04 - mean_squared_error: 8.3129e-04 - val_loss: 8.6147e-04 - val_mean_squared_error: 8.6147e-04
# Epoch 50/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.3114e-04 - mean_squared_error: 8.3115e-04 - val_loss: 8.6727e-04 - val_mean_squared_error: 8.6727e-04
# Epoch 51/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3031e-04 - mean_squared_error: 8.3031e-04 - val_loss: 8.6260e-04 - val_mean_squared_error: 8.6260e-04
# Epoch 52/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3029e-04 - mean_squared_error: 8.3029e-04 - val_loss: 8.6433e-04 - val_mean_squared_error: 8.6433e-04
# Epoch 53/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.3024e-04 - mean_squared_error: 8.3024e-04 - val_loss: 8.7177e-04 - val_mean_squared_error: 8.7177e-04
# Epoch 54/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.3049e-04 - mean_squared_error: 8.3049e-04 - val_loss: 8.6561e-04 - val_mean_squared_error: 8.6561e-04
# Epoch 55/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2871e-04 - mean_squared_error: 8.2871e-04 - val_loss: 8.6594e-04 - val_mean_squared_error: 8.6594e-04
# Epoch 56/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2934e-04 - mean_squared_error: 8.2934e-04 - val_loss: 8.6179e-04 - val_mean_squared_error: 8.6179e-04
# Epoch 57/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2872e-04 - mean_squared_error: 8.2872e-04 - val_loss: 8.6484e-04 - val_mean_squared_error: 8.6484e-04
# Epoch 58/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2869e-04 - mean_squared_error: 8.2869e-04 - val_loss: 8.6705e-04 - val_mean_squared_error: 8.6705e-04
# Epoch 59/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2829e-04 - mean_squared_error: 8.2829e-04 - val_loss: 8.6412e-04 - val_mean_squared_error: 8.6412e-04
# Epoch 60/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2847e-04 - mean_squared_error: 8.2847e-04 - val_loss: 8.6553e-04 - val_mean_squared_error: 8.6553e-04
# Epoch 61/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2748e-04 - mean_squared_error: 8.2748e-04 - val_loss: 8.5951e-04 - val_mean_squared_error: 8.5951e-04
# Epoch 62/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2745e-04 - mean_squared_error: 8.2745e-04 - val_loss: 8.7041e-04 - val_mean_squared_error: 8.7041e-04
# Epoch 63/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2742e-04 - mean_squared_error: 8.2742e-04 - val_loss: 8.6206e-04 - val_mean_squared_error: 8.6206e-04
# Epoch 64/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2738e-04 - mean_squared_error: 8.2738e-04 - val_loss: 8.6149e-04 - val_mean_squared_error: 8.6149e-04
# Epoch 65/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2697e-04 - mean_squared_error: 8.2697e-04 - val_loss: 8.6051e-04 - val_mean_squared_error: 8.6051e-04
# Epoch 66/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2696e-04 - mean_squared_error: 8.2696e-04 - val_loss: 8.6050e-04 - val_mean_squared_error: 8.6050e-04
# Epoch 67/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2639e-04 - mean_squared_error: 8.2640e-04 - val_loss: 8.7223e-04 - val_mean_squared_error: 8.7223e-04
# Epoch 68/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2596e-04 - mean_squared_error: 8.2596e-04 - val_loss: 8.6177e-04 - val_mean_squared_error: 8.6177e-04
# Epoch 69/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2534e-04 - mean_squared_error: 8.2534e-04 - val_loss: 8.6144e-04 - val_mean_squared_error: 8.6144e-04
# Epoch 70/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2575e-04 - mean_squared_error: 8.2575e-04 - val_loss: 8.6121e-04 - val_mean_squared_error: 8.6121e-04
# Epoch 71/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2617e-04 - mean_squared_error: 8.2617e-04 - val_loss: 8.6217e-04 - val_mean_squared_error: 8.6217e-04
# Epoch 72/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2495e-04 - mean_squared_error: 8.2495e-04 - val_loss: 8.6318e-04 - val_mean_squared_error: 8.6318e-04
# Epoch 73/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2480e-04 - mean_squared_error: 8.2480e-04 - val_loss: 8.6481e-04 - val_mean_squared_error: 8.6481e-04
# Epoch 74/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2440e-04 - mean_squared_error: 8.2440e-04 - val_loss: 8.6155e-04 - val_mean_squared_error: 8.6155e-04
# Epoch 75/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2488e-04 - mean_squared_error: 8.2488e-04 - val_loss: 8.6189e-04 - val_mean_squared_error: 8.6189e-04
# Epoch 76/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2421e-04 - mean_squared_error: 8.2421e-04 - val_loss: 8.6085e-04 - val_mean_squared_error: 8.6085e-04
# Epoch 77/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2381e-04 - mean_squared_error: 8.2380e-04 - val_loss: 8.5917e-04 - val_mean_squared_error: 8.5917e-04
# Epoch 78/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2378e-04 - mean_squared_error: 8.2378e-04 - val_loss: 8.5951e-04 - val_mean_squared_error: 8.5951e-04
# Epoch 79/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2366e-04 - mean_squared_error: 8.2366e-04 - val_loss: 8.5898e-04 - val_mean_squared_error: 8.5898e-04
# Epoch 80/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2294e-04 - mean_squared_error: 8.2294e-04 - val_loss: 8.6015e-04 - val_mean_squared_error: 8.6015e-04
# Epoch 81/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2329e-04 - mean_squared_error: 8.2329e-04 - val_loss: 8.5884e-04 - val_mean_squared_error: 8.5884e-04
# Epoch 82/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2257e-04 - mean_squared_error: 8.2257e-04 - val_loss: 8.6220e-04 - val_mean_squared_error: 8.6220e-04
# Epoch 83/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2293e-04 - mean_squared_error: 8.2293e-04 - val_loss: 8.5936e-04 - val_mean_squared_error: 8.5936e-04
# Epoch 84/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2228e-04 - mean_squared_error: 8.2228e-04 - val_loss: 8.5866e-04 - val_mean_squared_error: 8.5866e-04
# Epoch 85/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2233e-04 - mean_squared_error: 8.2233e-04 - val_loss: 8.6164e-04 - val_mean_squared_error: 8.6164e-04
# Epoch 86/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2153e-04 - mean_squared_error: 8.2153e-04 - val_loss: 8.5797e-04 - val_mean_squared_error: 8.5797e-04
# Epoch 87/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2183e-04 - mean_squared_error: 8.2183e-04 - val_loss: 8.6001e-04 - val_mean_squared_error: 8.6001e-04
# Epoch 88/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2129e-04 - mean_squared_error: 8.2129e-04 - val_loss: 8.5947e-04 - val_mean_squared_error: 8.5947e-04
# Epoch 89/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2116e-04 - mean_squared_error: 8.2116e-04 - val_loss: 8.6374e-04 - val_mean_squared_error: 8.6374e-04
# Epoch 90/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2120e-04 - mean_squared_error: 8.2120e-04 - val_loss: 8.5922e-04 - val_mean_squared_error: 8.5922e-04
# Epoch 91/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2104e-04 - mean_squared_error: 8.2104e-04 - val_loss: 8.5919e-04 - val_mean_squared_error: 8.5919e-04
# Epoch 92/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.2054e-04 - mean_squared_error: 8.2054e-04 - val_loss: 8.6239e-04 - val_mean_squared_error: 8.6239e-04
# Epoch 93/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2062e-04 - mean_squared_error: 8.2062e-04 - val_loss: 8.6020e-04 - val_mean_squared_error: 8.6020e-04
# Epoch 94/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2066e-04 - mean_squared_error: 8.2066e-04 - val_loss: 8.5931e-04 - val_mean_squared_error: 8.5931e-04
# Epoch 95/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.2013e-04 - mean_squared_error: 8.2013e-04 - val_loss: 8.6035e-04 - val_mean_squared_error: 8.6035e-04
# Epoch 96/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1992e-04 - mean_squared_error: 8.1992e-04 - val_loss: 8.6036e-04 - val_mean_squared_error: 8.6036e-04
# Epoch 97/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1990e-04 - mean_squared_error: 8.1990e-04 - val_loss: 8.5801e-04 - val_mean_squared_error: 8.5801e-04
# Epoch 98/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1979e-04 - mean_squared_error: 8.1979e-04 - val_loss: 8.6076e-04 - val_mean_squared_error: 8.6076e-04
# Epoch 99/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1924e-04 - mean_squared_error: 8.1924e-04 - val_loss: 8.5760e-04 - val_mean_squared_error: 8.5760e-04
# Epoch 100/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1935e-04 - mean_squared_error: 8.1935e-04 - val_loss: 8.6100e-04 - val_mean_squared_error: 8.6100e-04
# Epoch 101/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1909e-04 - mean_squared_error: 8.1908e-04 - val_loss: 8.5934e-04 - val_mean_squared_error: 8.5934e-04
# Epoch 102/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1900e-04 - mean_squared_error: 8.1900e-04 - val_loss: 8.5952e-04 - val_mean_squared_error: 8.5952e-04
# Epoch 103/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1848e-04 - mean_squared_error: 8.1848e-04 - val_loss: 8.5786e-04 - val_mean_squared_error: 8.5786e-04
# Epoch 104/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1834e-04 - mean_squared_error: 8.1834e-04 - val_loss: 8.6071e-04 - val_mean_squared_error: 8.6071e-04
# Epoch 105/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1847e-04 - mean_squared_error: 8.1848e-04 - val_loss: 8.5746e-04 - val_mean_squared_error: 8.5746e-04
# Epoch 106/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1796e-04 - mean_squared_error: 8.1796e-04 - val_loss: 8.6057e-04 - val_mean_squared_error: 8.6057e-04
# Epoch 107/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1829e-04 - mean_squared_error: 8.1829e-04 - val_loss: 8.6102e-04 - val_mean_squared_error: 8.6102e-04
# Epoch 108/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1774e-04 - mean_squared_error: 8.1774e-04 - val_loss: 8.6017e-04 - val_mean_squared_error: 8.6017e-04
# Epoch 109/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1750e-04 - mean_squared_error: 8.1750e-04 - val_loss: 8.5774e-04 - val_mean_squared_error: 8.5774e-04
# Epoch 110/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1770e-04 - mean_squared_error: 8.1770e-04 - val_loss: 8.6133e-04 - val_mean_squared_error: 8.6133e-04
# Epoch 111/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1705e-04 - mean_squared_error: 8.1705e-04 - val_loss: 8.5922e-04 - val_mean_squared_error: 8.5922e-04
# Epoch 112/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1730e-04 - mean_squared_error: 8.1730e-04 - val_loss: 8.6148e-04 - val_mean_squared_error: 8.6148e-04
# Epoch 113/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1724e-04 - mean_squared_error: 8.1724e-04 - val_loss: 8.6049e-04 - val_mean_squared_error: 8.6049e-04
# Epoch 114/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1643e-04 - mean_squared_error: 8.1643e-04 - val_loss: 8.8323e-04 - val_mean_squared_error: 8.8323e-04
# Epoch 115/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1654e-04 - mean_squared_error: 8.1654e-04 - val_loss: 8.6041e-04 - val_mean_squared_error: 8.6040e-04
# Epoch 116/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1685e-04 - mean_squared_error: 8.1685e-04 - val_loss: 8.5721e-04 - val_mean_squared_error: 8.5721e-04
# Epoch 117/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1617e-04 - mean_squared_error: 8.1617e-04 - val_loss: 8.6160e-04 - val_mean_squared_error: 8.6160e-04
# Epoch 118/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1605e-04 - mean_squared_error: 8.1605e-04 - val_loss: 8.5769e-04 - val_mean_squared_error: 8.5769e-04
# Epoch 119/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1594e-04 - mean_squared_error: 8.1594e-04 - val_loss: 8.5925e-04 - val_mean_squared_error: 8.5925e-04
# Epoch 120/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1567e-04 - mean_squared_error: 8.1567e-04 - val_loss: 8.5697e-04 - val_mean_squared_error: 8.5697e-04
# Epoch 121/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1551e-04 - mean_squared_error: 8.1551e-04 - val_loss: 8.5868e-04 - val_mean_squared_error: 8.5868e-04
# Epoch 122/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1512e-04 - mean_squared_error: 8.1512e-04 - val_loss: 8.5833e-04 - val_mean_squared_error: 8.5833e-04
# Epoch 123/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1537e-04 - mean_squared_error: 8.1537e-04 - val_loss: 8.6049e-04 - val_mean_squared_error: 8.6049e-04
# Epoch 124/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1483e-04 - mean_squared_error: 8.1483e-04 - val_loss: 8.5733e-04 - val_mean_squared_error: 8.5733e-04
# Epoch 125/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1493e-04 - mean_squared_error: 8.1493e-04 - val_loss: 8.6101e-04 - val_mean_squared_error: 8.6101e-04
# Epoch 126/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1499e-04 - mean_squared_error: 8.1499e-04 - val_loss: 8.5935e-04 - val_mean_squared_error: 8.5935e-04
# Epoch 127/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1446e-04 - mean_squared_error: 8.1446e-04 - val_loss: 8.5863e-04 - val_mean_squared_error: 8.5863e-04
# Epoch 128/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1419e-04 - mean_squared_error: 8.1419e-04 - val_loss: 8.5737e-04 - val_mean_squared_error: 8.5737e-04
# Epoch 129/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1433e-04 - mean_squared_error: 8.1433e-04 - val_loss: 8.5771e-04 - val_mean_squared_error: 8.5771e-04
# Epoch 130/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1390e-04 - mean_squared_error: 8.1390e-04 - val_loss: 8.5735e-04 - val_mean_squared_error: 8.5735e-04
# Epoch 131/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1344e-04 - mean_squared_error: 8.1344e-04 - val_loss: 8.5711e-04 - val_mean_squared_error: 8.5711e-04
# Epoch 132/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1380e-04 - mean_squared_error: 8.1380e-04 - val_loss: 8.5834e-04 - val_mean_squared_error: 8.5834e-04
# Epoch 133/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1376e-04 - mean_squared_error: 8.1376e-04 - val_loss: 8.5772e-04 - val_mean_squared_error: 8.5772e-04
# Epoch 134/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1278e-04 - mean_squared_error: 8.1278e-04 - val_loss: 8.6168e-04 - val_mean_squared_error: 8.6168e-04
# Epoch 135/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1315e-04 - mean_squared_error: 8.1315e-04 - val_loss: 8.6166e-04 - val_mean_squared_error: 8.6166e-04
# Epoch 136/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1325e-04 - mean_squared_error: 8.1325e-04 - val_loss: 8.5799e-04 - val_mean_squared_error: 8.5799e-04
# Epoch 137/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1282e-04 - mean_squared_error: 8.1282e-04 - val_loss: 8.5808e-04 - val_mean_squared_error: 8.5808e-04
# Epoch 138/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1277e-04 - mean_squared_error: 8.1277e-04 - val_loss: 8.5621e-04 - val_mean_squared_error: 8.5621e-04
# Epoch 139/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1238e-04 - mean_squared_error: 8.1238e-04 - val_loss: 8.5730e-04 - val_mean_squared_error: 8.5730e-04
# Epoch 140/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1275e-04 - mean_squared_error: 8.1275e-04 - val_loss: 8.6149e-04 - val_mean_squared_error: 8.6149e-04
# Epoch 141/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1217e-04 - mean_squared_error: 8.1217e-04 - val_loss: 8.6167e-04 - val_mean_squared_error: 8.6167e-04
# Epoch 142/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1204e-04 - mean_squared_error: 8.1204e-04 - val_loss: 8.5836e-04 - val_mean_squared_error: 8.5836e-04
# Epoch 143/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1162e-04 - mean_squared_error: 8.1162e-04 - val_loss: 8.5790e-04 - val_mean_squared_error: 8.5790e-04
# Epoch 144/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1181e-04 - mean_squared_error: 8.1181e-04 - val_loss: 8.5652e-04 - val_mean_squared_error: 8.5652e-04
# Epoch 145/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1149e-04 - mean_squared_error: 8.1150e-04 - val_loss: 8.5625e-04 - val_mean_squared_error: 8.5625e-04
# Epoch 146/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1203e-04 - mean_squared_error: 8.1203e-04 - val_loss: 8.6066e-04 - val_mean_squared_error: 8.6067e-04
# Epoch 147/150
# 840/840 [==============================] - 14s 16ms/step - loss: 8.1161e-04 - mean_squared_error: 8.1161e-04 - val_loss: 8.5865e-04 - val_mean_squared_error: 8.5865e-04
# Epoch 148/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1097e-04 - mean_squared_error: 8.1097e-04 - val_loss: 8.5728e-04 - val_mean_squared_error: 8.5728e-04
# Epoch 149/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1118e-04 - mean_squared_error: 8.1118e-04 - val_loss: 8.5628e-04 - val_mean_squared_error: 8.5628e-04
# Epoch 150/150
# 840/840 [==============================] - 13s 16ms/step - loss: 8.1117e-04 - mean_squared_error: 8.1117e-04 - val_loss: 8.5771e-04 - val_mean_squared_error: 8.5771e-04

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %%
h = history.history
plt.plot(h['loss'])
plt.plot(h['val_loss'])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
path=r"/content/drive/My Drive/srcnn"
srcnn.save(path+"/model1.h5")

# %%
test_path="/content/drive/My Drive/srcnn/dataset/val/low_res/0.png"
img = cv2.imread(test_path, cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
shape = img.shape
Y_img = cv2.resize(img[:, :, 0], (shape[1] // 2, shape[0] // 2), cv2.INTER_CUBIC)
Y_img = cv2.resize(Y_img, (shape[1], shape[0]), cv2.INTER_CUBIC)
img[:, :, 0] = Y_img
img = cv2.cvtColor(img, cv2.COLOR_YCrCb2BGR)

Y = np.zeros((1, img.shape[0], img.shape[1], 1), dtype=float)
Y[0, :, :, 0] = Y_img.astype(float) / 255.
pre = srcnn.predict(Y, batch_size=1) * 255.
pre[pre[:] > 255] = 255
pre[pre[:] < 0] = 0
pre = pre.astype(np.uint8)
img = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
img[6: -6, 6: -6, 0] = pre[0, :, :, 0]
img = cv2.cvtColor(img, cv2.COLOR_YCrCb2BGR)

# %%
plt.imshow(cv2.imread(test_path))

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.imread("/content/drive/My Drive/srcnn/dataset/val/high_res/0.png"))

# %% [markdown]
# [Check this again ](https://github.com/MarkPrecursor/SRCNN-keras/blob/master/main.py)
# xoxo we will nail it don't you worry child.
